# %% [markdown]
# # ZView Demo
#
# This notebook shows the standalone demo scene and the BeamZ-like adapter path.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if not (repo_root / "src").exists() and (repo_root.parent / "src").exists():
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root / "src"))

from zview import demo_scene, view3d

view3d(demo_scene())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 11
#       7 sys.path.insert(0, str(repo_root / "src"))
#       9 from zview import demo_scene, view3d
# ---> 11 view3d(demo_scene())
#
# File ~/Code/zview/src/zview/_widget.py:91, in view3d(value, mode, open_browser, **kwargs)
#      89 if chosen_mode != "widget":
#      90     raise ValueError("mode must be one of: 'auto', 'widget', 'browser'")
# ---> 91 return ZViewWidget(scene=scene, **kwargs)
#
# File ~/Code/zview/src/zview/_widget.py:41, in ZViewWidget.__init__(self, scene, **kwargs)
#      39 def __init__(self, scene: SceneSpec | dict[str, Any], **kwargs: Any) -> None:
#      40     if anywidget is None:
# ---> 41         raise RuntimeError(
#      42             "Rendering ZViewWidget requires `anywidget`. Install zview with the `widget` extra."
#      43         )
#      44     scene_spec = scene if isinstance(scene, SceneSpec) else scene_from_dict(scene)
#      45     scene_json = scene_spec.to_dict()
#
# RuntimeError: Rendering ZViewWidget requires `anywidget`. Install zview with the `widget` extra.

# %%
from pathlib import Path
import importlib.util

examples_dir = repo_root / "examples"
demo_path = examples_dir / "demo_beamz_like.py"
spec = importlib.util.spec_from_file_location("demo_beamz_like", demo_path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

module.view3d(module.make_design())
